# %%
import pandas as pd

# %%
#https://showdata.gks.ru/report/279006/#

# %%
data = pd.read_html('file:///C:/Users/user/Downloads/23320000100030200005_%D0%9C%D0%B8%D0%B3%D1%80%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%BF%D1%80%D0%B8%D1%80%D0%BE%D1%81%D1%82_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BF%D0%BE_%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D0%B0%D0%BC_%D1%81_%D1%87%D0%B8%D1%81%D0%BB%D0%BE%D0%BC_%D0%B6%D0%B8%D1%82%D0%B5%D0%BB%D0%B5%D0%B9_100_%D1%82%D1%8B%D1%81__%D1%87%D0%B5%D0%BB%D0%BE%D0%B2%D0%B5%D0%BA_%D0%B8_%D0%B1.html')

# %%
data[0]
# Out:
#                Unnamed: 0    Unnamed: 1  \
# 0                     NaN           NaN
# 1       В пределах России  5.200000e+01
# 2                Белгород  1.440100e+10
# 3            Старый Оскол  1.444000e+10
# 4                  Брянск  1.540100e+10
# ..                    ...           ...
# 139               Находка  5.414000e+09
# 140             Уссурийск  5.423000e+09
# 141             Хабаровск  8.401000e+09
# 142  Комсомольск-на-Амуре  8.409000e+09
# 143          Благовещенск  1.040100e+10
#
#     23320000100030200005 Миграционный прирост населения по городам с числом жителей 100 тыс. человек и более  \
# 0                                              2013 г.
# 1                                                  NaN
# 2                                                 4869
# 3                                                 -753
# 4                                                -1329
# ..                                                 ...
# ...
